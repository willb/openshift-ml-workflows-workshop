# %%
import pandas as pd
data = pd.read_parquet("data/training.parquet")

# %%
data
# Out:
#                                                     text      whence
# 0      You must write to me. Catherine sighed. And th...  legitimate
# 1      Who would have thought Mr. Crawford sure of he...  legitimate
# 2      He had only himself to please in his choice: h...  legitimate
# 3      Oh! One accompaniment to her song took her agr...  legitimate
# 4      As soon as breakfast was over, she went to her...  legitimate
# 5      Mrs Clay's selfishness was not so great as to ...  legitimate
# 6      But self, though it would intrude, could not e...  legitimate
# 7      Elizabeth, though she did not wish to slight. ...  legitimate
# 8      Edmund had descended from that moral elevation...  legitimate
# 9      I read up on the morrow the Crawfords were eng...  legitimate
# 10     But even this encouragement failed, for he wou...  legitimate
# 11     All the better. Catherine's silent appeal to h...  legitimate
# 12     Got me about 250 feet in a battle.. Their jour...  legitimate
# 13     For ten minutes she could hear of no situation...  legitimate
# 14     She had a little better with milk, but kids or...  legitimate
# 15     These feelings rapidly restored his comfort, w...  legitimate
# 16     They found Mr. Bennet still up. That, from suc...  legitimate
# 17     They have a odd plastic kinda of taste. He rep...  legitimate
# 18     I hope you will think better of their looks to...  legitimate
# 19     The minute they hear the pouch open! So I will...  legitimate
# 20     I will order this item from this company as lo...  legitimate
# 21     Mr. Dashwood's strains were more solemn. The b...  legitimate
# 22     Quite frankly, if you are speaking of music. L...  legitimate
# 23     Then passing through the great gates of the lo...  legitimate
# 24     I love the taste of the furniture. So far he a...  legitimate
# 25     The Foundation's principal office is located a...  legitimate
# 26     Everybody likes to go their own way--to chuse ...  legitimate
# 27     As soon as she possibly could, of his servants...  legitimate
# 28     I'm a big tea drinker but can't find them here...  legitimate
# 29     We've bought some of these and they've turned ...  legitimate
# ...                                                  ...         ...
# 19970  Recommended product. i already had one law sui...        spam
# 19971  Then found that if the flavor you get in each ...        spam
# 19972  Goes up the sinuses, too. Well since this is t...        spam
# 19973  I hope we just got a bad batch, it must be the...        spam
# 19974  I originally decided to purchase the African N...        spam
# 19975  It is very effective have used it in and leave...        spam
# 19976  This is my favorite of all the hamburger helpe...        spam
# 19977  Unfortunately it doesn't have that sickly swee...        spam
# 19978  They are also a healthier snacking option than...        spam
# 19979  Cheap.The worst part though was the scent. But...        spam
# 19980  Bought these for my dog...first of all, they'r...        spam
# 19981  You don't need to take a pill. I don't care if...        spam
# 19982  If it doesn't look and feel of the confection ...        spam
# 19983  The oil used is soybean oil. It is definitely ...        spam
# 19984  Finally it dawned on me that due to the blend/...        spam
# 19985  I never thought I would give this a try! It is...        spam
# 19986  Very good lime flavor and have a great mild ch...        spam
# 19987  My doctor recommended almonds as an cheaper al...        spam
# 19988  This is very good as it has a good flavor, and...        spam
# 19989  I've tried numerous coffee candies and this is...        spam
# 19990  I'm very disappointed. Hmmmmmmm. Thanks for th...        spam
# 19991  As I mentioned, I really enjoy the levels of c...        spam
# 19992  Anyway, these are highly addictive. These are ...        spam
# 19993  I will definitely order more! just a nice bit ...        spam
# 19994  Just add water, oil & egg and stir. Just... ho...        spam
# 19995  Shortly after I wrote my first review on Amazo...        spam
# 19996  Eat this delicious cereal with the confidence ...        spam
# 19997  Length:: 2:09 MinsMy eight-year-old son volunt...        spam
# 19998  Dieting since mid-May using whole grains in a ...        spam
# 19999  My wife's excitement quickly turned to disappo...        spam
#
# [40000 rows x 2 columns]

# %%
import spacy
english = spacy.load("en")

# %%
data["text"].get_values()[0]
# Out:
# "You must write to me. Catherine sighed. And there are other circumstances which I am now satisfied that I never brewed it. They will read together. Her praise had been given her at different times, but _this_ is the true one. So surrounded, so caressed, she was even positively civil; but it was not directed to me--it was to Mrs. Weston. And besides the operation of a sensible, intelligent man like Mr. Allen. I see that more than a little proud-looking woman of uncordial address, who met her husband's sisters without any affection, and almost without beauty. I walked over the the vending machine so I am very sorry--extremely sorry--But, Miss Smith, indeed!--Oh! Could she but have given Harriet her feelings about it all!"

# %%
doc = english(data["text"].get_values()[0])

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# We can use spaCy to identify parts of speech.

# %%
for token in doc:
    print("%s is a %s" % (token.text, token.pos_))
# Out:
# You is a PRON
# must is a VERB
# write is a VERB
# to is a ADP
# me is a PRON
# . is a PUNCT
# Catherine is a PROPN
# sighed is a VERB
# . is a PUNCT
# And is a CCONJ
# there is a ADV
# are is a VERB
# other is a ADJ
# circumstances is a NOUN
# which is a ADJ
# I is a PRON
# am is a VERB
# now is a ADV
# satisfied is a ADJ
# that is a ADP
# I is a PRON
# never is a ADV
# brewed is a VERB
# it is a PRON
# . is a PUNCT
# They is a PRON
# will is a VERB
# read is a VERB
# together is a ADV
# . is a PUNCT
# Her is a ADJ
# praise is a NOUN
# had is a VERB
# been is a VERB
# given is a VERB
# her is a PRON
# at is a ADP
# different is a ADJ
# times is a NOUN
# , is a PUNCT
# but is a CCONJ
# _ is a VERB
# this is a DET
# _ is a NOUN
# is is a VERB
# the is a DET
# true is a ADJ
# one is a NOUN
# . is a PUNCT
# So is a ADV
# surrounded is a VERB
# , is a PUNCT
# so is a ADV
# caressed is a ADJ
# , is a PUNCT
# she is a PRON
# was is a VERB
# even is a ADV
# positively is a ADV
# civil is a ADJ
# ; is a PUNCT
# but is a CCONJ
# it is a PRON
# was is a VERB
# not is a ADV
# directed is a VERB
# to is a ADP
# me is a PRON
# -- is a PUNCT
# it is a PRON
# was is a VERB
# to is a ADP
# Mrs. is a PROPN
# Weston is a PROPN
# . is a PUNCT
# And is a CCONJ
# besides is a ADP
# the is a DET
# operation is a NOUN
# of is a ADP
# a is a DET
# sensible is a ADJ
# , is a PUNCT
# intelligent is a ADJ
# man is a NOUN
# like is a ADP
# Mr. is a PROPN
# Allen is a PROPN
# . is a PUNCT
# I is a PRON
# see is a VERB
# that is a ADP
# more is a ADJ
# than is a ADP
# a is a DET
# little is a ADJ
# proud is a ADJ
# - is a PUNCT
# looking is a VERB
# woman is a NOUN
# of is a ADP
# uncordial is a ADJ
# address is a NOUN
# , is a PUNCT
# who is a NOUN
# met is a VERB
# her is a ADJ
# husband is a NOUN
# 's is a PART
# sisters is a NOUN
# without is a ADP
# any is a DET
# affection is a NOUN
# , is a PUNCT
# and is a CCONJ
# almost is a ADV
# without is a ADP
# beauty is a NOUN
# . is a PUNCT
# I is a PRON
# walked is a VERB
# over is a ADP
# the is a DET
# the is a DET
# vending is a VERB
# machine is a NOUN
# so is a ADP
# I is a PRON
# am is a VERB
# very is a ADV
# sorry is a ADJ
# -- is a PUNCT
# extremely is a ADV
# sorry is a ADJ
# -- is a PUNCT
# But is a CCONJ
# , is a PUNCT
# Miss is a PROPN
# Smith is a PROPN
# , is a PUNCT
# indeed!--Oh is a PROPN
# ! is a PUNCT
# Could is a VERB
# she is a PRON
# but is a CCONJ
# have is a VERB
# given is a VERB
# Harriet is a PROPN
# her is a ADJ
# feelings is a NOUN
# about is a ADP
# it is a PRON
# all is a DET
# ! is a PUNCT

# %% [markdown]
# We can also use spaCy to identify the base forms of words -- it does this with a combination of part-of-speech-specific rules and a dictionary of exceptions.  The spaCy component that does this is called a [_lemmatizer_](https://en.wikipedia.org/wiki/Lemma_%28morphology%29).

# %%
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en import LEMMA_INDEX, LEMMA_EXC, LEMMA_RULES
lemmatizer = Lemmatizer(LEMMA_INDEX, LEMMA_EXC, LEMMA_RULES)

# %%
for token in doc:
    print("%s has a base form of %s" % (token.text, lemmatizer(token.text, token.pos_)))
# Out:
# You gets lemmatized to ['you']
# must gets lemmatized to ['must']
# write gets lemmatized to ['write']
# to gets lemmatized to ['to']
# me gets lemmatized to ['me']
# . gets lemmatized to ['.']
# Catherine gets lemmatized to ['catherine']
# sighed gets lemmatized to ['sigh']
# . gets lemmatized to ['.']
# And gets lemmatized to ['and']
# there gets lemmatized to ['there']
# are gets lemmatized to ['be']
# other gets lemmatized to ['othe', 'oth']
# circumstances gets lemmatized to ['circumstance']
# which gets lemmatized to ['which']
# I gets lemmatized to ['i']
# am gets lemmatized to ['be']
# now gets lemmatized to ['now']
# satisfied gets lemmatized to ['satisfied']
# that gets lemmatized to ['that']
# I gets lemmatized to ['i']
# never gets lemmatized to ['never']
# brewed gets lemmatized to ['brew']
# it gets lemmatized to ['it']
# . gets lemmatized to ['.']
# They gets lemmatized to ['they']
# will gets lemmatized to ['will']
# read gets lemmatized to ['read']
# together gets lemmatized to ['together']
# . gets lemmatized to ['.']
# Her gets lemmatized to ['h', 'he']
# praise gets lemmatized to ['praise']
# had gets lemmatized to ['have']
# been gets lemmatized to ['be']
# given gets lemmatized to ['give']
# her gets lemmatized to ['her']
# at gets lemmatized to ['at']
# different gets lemmatized to ['different']
# times gets lemmatized to ['time']
# , gets lemmatized to [',']
# but gets lemmatized to ['but']
# _ gets lemmatized to ['_']
# this gets lemmatized to ['this']
# _ gets lemmatized to ['_']
# is gets lemmatized to ['be']
# the gets lemmatized to ['the']
# true gets lemmatized to ['true']
# one gets lemmatized to ['one']
# . gets lemmatized to ['.']
# So gets lemmatized to ['so']
# surrounded gets lemmatized to ['surround']
# , gets lemmatized to [',']
# so gets lemmatized to ['so']
# caressed gets lemmatized to ['caressed']
# , gets lemmatized to [',']
# she gets lemmatized to ['she']
# was gets lemmatized to ['be']
# even gets lemmatized to ['even']
# positively gets lemmatized to ['positively']
# civil gets lemmatized to ['civil']
# ; gets lemmatized to [';']
# but gets lemmatized to ['but']
# it gets lemmatized to ['it']
# was gets lemmatized to ['be']
# not gets lemmatized to ['not']
# directed gets lemmatized to ['direct']
# to gets lemmatized to ['to']
# me gets lemmatized to ['me']
# -- gets lemmatized to ['--']
# it gets lemmatized to ['it']
# was gets lemmatized to ['be']
# to gets lemmatized to ['to']
# Mrs. gets lemmatized to ['mrs.']
# Weston gets lemmatized to ['weston']
# . gets lemmatized to ['.']
# And gets lemmatized to ['and']
# besides gets lemmatized to ['besides']
# the gets lemmatized to ['the']
# operation gets lemmatized to ['operation']
# of gets lemmatized to ['of']
# a gets lemmatized to ['a']
# sensible gets lemmatized to ['sensible']
# , gets lemmatized to [',']
# intelligent gets lemmatized to ['intelligent']
# man gets lemmatized to ['man']
# like gets lemmatized to ['like']
# Mr. gets lemmatized to ['mr.']
# Allen gets lemmatized to ['allen']
# . gets lemmatized to ['.']
# I gets lemmatized to ['i']
# see gets lemmatized to ['see']
# that gets lemmatized to ['that']
# more gets lemmatized to ['more']
# than gets lemmatized to ['than']
# a gets lemmatized to ['a']
# little gets lemmatized to ['little']
# proud gets lemmatized to ['proud']
# - gets lemmatized to ['-']
# looking gets lemmatized to ['look']
# woman gets lemmatized to ['woman']
# of gets lemmatized to ['of']
# uncordial gets lemmatized to ['uncordial']
# address gets lemmatized to ['addres']
# , gets lemmatized to [',']
# who gets lemmatized to ['who']
# met gets lemmatized to ['meet']
# her gets lemmatized to ['h', 'he']
# husband gets lemmatized to ['husband']
# 's gets lemmatized to ["'s"]
# sisters gets lemmatized to ['sister']
# without gets lemmatized to ['without']
# any gets lemmatized to ['any']
# affection gets lemmatized to ['affection']
# , gets lemmatized to [',']
# and gets lemmatized to ['and']
# almost gets lemmatized to ['almost']
# without gets lemmatized to ['without']
# beauty gets lemmatized to ['beauty']
# . gets lemmatized to ['.']
# I gets lemmatized to ['i']
# walked gets lemmatized to ['walk']
# over gets lemmatized to ['over']
# the gets lemmatized to ['the']
# the gets lemmatized to ['the']
# vending gets lemmatized to ['vend']
# machine gets lemmatized to ['machine']
# so gets lemmatized to ['so']
# I gets lemmatized to ['i']
# am gets lemmatized to ['be']
# very gets lemmatized to ['very']
# sorry gets lemmatized to ['sorry']
# -- gets lemmatized to ['--']
# extremely gets lemmatized to ['extremely']
# sorry gets lemmatized to ['sorry']
# -- gets lemmatized to ['--']
# But gets lemmatized to ['but']
# , gets lemmatized to [',']
# Miss gets lemmatized to ['miss']
# Smith gets lemmatized to ['smith']
# , gets lemmatized to [',']
# indeed!--Oh gets lemmatized to ['indeed!--oh']
# ! gets lemmatized to ['!']
# Could gets lemmatized to ['could']
# she gets lemmatized to ['she']
# but gets lemmatized to ['but']
# have gets lemmatized to ['have']
# given gets lemmatized to ['give']
# Harriet gets lemmatized to ['harriet']
# her gets lemmatized to ['h', 'he']
# feelings gets lemmatized to ['feeling']
# about gets lemmatized to ['about']
# it gets lemmatized to ['it']
# all gets lemmatized to ['all']
# ! gets lemmatized to ['!']

# %% [markdown]
# We can apply this process to the entire data frame if we'd like, but it might take a while.

# %%
def lemmas(s):
    return " ".join([lemmatizer(token.text, token.pos_)[0] for token in english(s)])

data["lemmas"] = data["text"].apply(lemmas,1)
