# %% [markdown]
# # Data Drift
#
#
# Suppose the spam generator becomes more intelligent and begins producing prose which looks "more legitimate" than before. Data drift occurs when the data the model was trained on no longer accurately reflects the data that the model is currently analyzing. Drift can take on different forms, to illustrate a few:
#  + The structure of data may change. Maybe spam emails start utilizing photo attachments rather than text. Since our model is based off of text within the email, it would likely start performing very poorly.
#  + Data can change meaning, even if structure does not. Perhaps spam mail about food becomes our new favorite reading to go along with morning coffee, and we no longer want that type of spam filtered out of our mailbox.
#  + Features may change. Features that are previously infrequent may become more frequent, or vice versa. One (unlikely) drift could be that all modern spam emails begin containing the word "coffee" and never the word "tree." This could be an important insight to include in our model.
#
# Data drift appears in many subtle ways, causing models to become useless without ever notifying the user that an error has occurred. Models with changing data need to be monitored to ensure that the model is still performing as expected.
#
# We'll start exploring data drift by importing the data used in previous notebooks.

# %%
import pandas as pd
import os.path

df = pd.read_parquet(os.path.join("data", "training.parquet"))

# %% [markdown]
# We split the data into training and testing sets, as in the modelling notebooks. We use the `random_state` parameter to ensure that the data is split in the same way as it was when we fit the model.

# %%
from sklearn import model_selection

df_train, df_test = model_selection.train_test_split(df, random_state=43)
df_test_spam = df_test[df_test.label == 'spam'].copy() #filter the spam documents

# %% [markdown]
# Then, we filter out the spam and force the spam data to drift by adding the first few lines of Pride and Prejudice to the start of the spam documents in our testing set.

# %%
def add_text(doc, adds):
    """
    takes in a string _doc_ and
    appends text _adds_ to the start
    """
    
    return adds + doc

# %%
pride_pred = '''It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.However little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.“My dear Mr. Bennet,” said his lady to him one day, “have you heard that Netherfield Park is let at last?” Mr. Bennet replied that he had not. “But it is,” returned she; “for Mrs. Long has just been here, and she told me all about it.” Mr. Bennet made no answer. “Do you not want to know who has taken it?” cried his wife impatiently.'''

# %%
# appending text to the start of the spam
df_test_spam["text"] = df_test_spam.text.apply(add_text, adds=pride_pred)

# %%
pd.set_option('display.max_colwidth', None) # ensures that all the text is visible
df_test_spam.sample(3)
# Out:
#        index label  \
# 26926   6926  spam
# 28204   8204  spam
# 22033   2033  spam
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              text
# 26926                        It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.However little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.“My dear Mr. Bennet,” said his lady to him one day, “have you heard that Netherfield Park is let at last?” Mr. Bennet replied that he had not. “But it is,” returned she; “for Mrs. Long has just been here, and she told me all about it.” Mr. Bennet made no answer. “Do you not want to know who has taken it?” cried his wife impatiently.However, I understand why so many folks are addicted to these tuna treats, and the Bengal boy almost went berserk trying to get away from drinking diet drinks does not help when the hassle arrives. They are perfectly silky, and have a richer flavor than any of the other Cappucino K Cup knock offs. Highly recommend!!! My sweet daughter loves these. I decide to finish this bag. Really, really great.
# 28204                                                                                                                                                                                                                                                                         It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.However little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.“My dear Mr. Bennet,” said his lady to him one day, “have you heard that Netherfield Park is let at last?” Mr. Bennet replied that he had not. “But it is,” returned she; “for Mrs. Long has just been here, and she told me all about it.” Mr. Bennet made no answer. “Do you not want to know who has taken it?” cried his wife impatiently.It says it kills over 200 weeds. Plenty of caffaine to start my second 16oz. can. The coffee in the K-cups has the best price. We have tried all their flavors.
# 22033  It is a truth universally acknowledged, that a single man in possession of a good fortune, must be in want of a wife.However little known the feelings or views of such a man may be on his first entering a neighbourhood, this truth is so well fixed in the minds of the surrounding families, that he is considered the rightful property of some one or other of their daughters.“My dear Mr. Bennet,” said his lady to him one day, “have you heard that Netherfield Park is let at last?” Mr. Bennet replied that he had not. “But it is,” returned she; “for Mrs. Long has just been here, and she told me all about it.” Mr. Bennet made no answer. “Do you not want to know who has taken it?” cried his wife impatiently.These are both dark and flavorful and work great in place of a candy bar. I live in New Jersey, so pork rinds are the best of green tea's. I will give an odd taste. They are perfect to satisfy my craving. So no harsh chemicals you find in the grocery store. Use as a garnish, the texture of the snack I grab when my throat is sore. I loved these growing up and now after several days they are OK again and eating normally.

# %% [markdown]
# We now pass this "drifted" data through the pipeline we created: we compute feature vectors, and we make spam/legitimate classifications using the model we trained.

# %%
from sklearn.pipeline import Pipeline
import pickle, os

# loading in feature vectors pipeline
filename = 'feature_pipeline.sav'
feat_pipeline = pickle.load(open(filename, 'rb'))

# loading model
filename = 'model.sav'
model = pickle.load(open(filename, 'rb'))

feature_pipeline = Pipeline([
    ('features',feat_pipeline)
])

# %% [markdown]
# Next, we use our feature engineering pipeline to transform the data into feature vectors. We'll then use PCA (discussed in the [visualization](01-vectors-and-visualization.ipynb) notebook) to map these large vectors to 2 dimensions so we can view the structure of the new spam data.

# %%
ft_train_data = feature_pipeline.fit_transform(df_train["text"], df_train["label"])
ft_drifted_data = feature_pipeline.fit_transform(df_test_spam["text"], df_test_spam["label"])

# %%
import sklearn.decomposition

DIMENSIONS = 2
pca = sklearn.decomposition.TruncatedSVD(DIMENSIONS)

# fit_transform original data, put into data frame
pca_a = pca.fit_transform(ft_train_data)
pca_df = pd.DataFrame(pca_a, columns=["x", "y"])

# transform new spam data, put into data frame
pca_b = pca.transform(ft_drifted_data)
pca_df_drift = pd.DataFrame(pca_b, columns=["x", "y"])

# %%
df_t
# Out:
#        level_0  index         label  \
# 0            0      0    legitimate
# 1            1      1    legitimate
# 2            2      2    legitimate
# 3            3      3    legitimate
# 4            4      4    legitimate
# ...        ...    ...           ...
# 39995    39995  19995  drifted spam
# 39996    39996  19996  drifted spam
# 39997    39997  19997  drifted spam
# 39998    39998  19998  drifted spam
# 39999    39999  19999  drifted spam
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 0                                         You must write to me. Catherine sighed. And there are other circumstances which I am now satisfied that I never brewed it. They will read together. Her praise had been given her at different times, but _this_ is the true one. So surrounded, so caressed, she was even positively civil; but it was not directed to me--it was to Mrs. Weston. And besides the operation of a sensible, intelligent man like Mr. Allen. I see that more than a little proud-looking woman of uncordial address, who met her husband's sisters without any affection, and almost without beauty. I walked over the the vending machine so I am very sorry--extremely sorry--But, Miss Smith, indeed!--Oh! Could she but have given Harriet her feelings about it all!
# 1                                                                                                                                                                                                                                                Who would have thought Mr. Crawford sure of her, and whether, in defiance of honour and honesty would have led his fair partner away, but she resisted. Elizabeth was now most heartily sorry that she had no intellectual superiority to make atonement to herself, or of strengthening his views in favour of Northamptonshire. What is it about? His opinion, however, made some little amends for his delay, for though acknowledging a very unexpected guest with us at present, my dear Mother: he arrived yesterday. Total calories = 190.
# 2      He had only himself to please in his choice: his fortune was moderate and must be taken; and as she returned by a different manufacturer. With the exception of Lady Bertram, Mrs. Norris, and she carefully refused him every opportunity. If he had but my picture, he says he should be old enough to make his wife understand his character. The more I think of the faithless Edward, or why I weep when I behold his Bride, for too surely this is the type of treat. But Mrs. Dashwood, trusting to the temperate account of her own beauty. How can they suit each other? Crawford had been obliged to meet! But you I am truly glad, dearest Lizzy, that you have such pleasant accounts from our friends at Hunsford. She wished, however to see the place again. Amazing flavor.
# 3                                                                                                                                                                                                                                            Oh! One accompaniment to her song took her agreeably by surprize--a second, slightly but correctly taken by Frank Churchill. Would they but love her, she should be perfectly satisfied.--Let him but continue the same Mr. Crawford whom she had been in the way of recovering her husband's property in the place of a parent. Mrs. Allen, are not you of my readiness to make them for a little respite of her weekly cares, and only discomposed if she saw her eagerly examining every morning. Amazon is the best brand for Kcups I have tried.
# 4                                                                                                                                                                                                                                                                                                                                        As soon as breakfast was over, she went to her sister. But there is one thing more preparing against him, which must be laid before Emma. Soon after their reaching the bottom of the packet on chicken, which also came out real green and thick. We have found that buying it here is great. How unlucky! Sometimes it had hints of coffee. Two obstacles of the five being thus removed, Mrs. Bennet sat looking and winking at Elizabeth and herself.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# 39995                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shortly after I wrote my first review on Amazon. Too much time and gas money. I have gone through about 8 bags in each box, when in reality the label on everything I can, sandwiches, tacos, quesodillas, salads, beans and even now as an adult at least. I really enjoyed this bread.
# 39996                                                                                                                                                                                                                                                                                                                                                                                                        Eat this delicious cereal with the confidence that it was offered at a good price. It was more like mystery meat, and there just isn't much to say. I highly recommend considering for triathletes out there looking for something a little more tough. I normally only drink one cup of coffee available.Make no mistake about it. They might as well be pouring it down the toilet.
# 39997                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Length:: 2:09 MinsMy eight-year-old son volunteered to try Nong Shim's new flavor, spicy chicken. I eat alot of mayo so I need something to drink and came across these. I made the order. I can hardly eat this for a cookie recipe and STILL could not discern any flavor hazelnut or otherwise!
# 39998                                                                                                                                                                                                                                                                                           Dieting since mid-May using whole grains in a tasty way! There was no sweetness at all, no honey taste at all, look like a lot of sugars...but when I eat them, they finally leave my wife and I both tried these and the the bride loved it. I must warn you, these are simply THE best cheese curls. Okay, they woofed it down so much it was over-powering like a full robust flavor, and will see if i continue to buy Popchips but never the salt and that was because of all the other jars.
# 39999                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    My wife's excitement quickly turned to disappointment. The colors are great and a good rice washing bowl.
#
#               x         y
# 0      0.636576 -0.111214
# 1      0.591329  0.004632
# 2      0.589513 -0.007253
# 3      0.573062 -0.043787
# 4      0.583722 -0.048636
# ...         ...       ...
# 39995       NaN       NaN
# 39996       NaN       NaN
# 39997       NaN       NaN
# 39998       NaN       NaN
# 39999       NaN       NaN
#
# [40000 rows x 6 columns]

# %%
import altair as alt
from altair.expr import datum
alt.renderers.enable('notebook')
SAMPLE = 2000
plot_data = pd.concat([df.reset_index(), pca_df], axis=1)

plot_data["label"]= plot_data["label"].replace("spam", "previous spam")
plot_data_drift = pd.concat([df.reset_index(), pca_df_drift], axis=1)
plot_data_drift["label"] = plot_data_drift["label"].replace("spam", "drifted spam")
plot_data2 = pd.concat([plot_data_drift, plot_data])

domain = ['legitimate', 'previous spam', 'drifted spam']
range_ = ['lightgray', 'blue', 'red']
chart1 = alt.Chart(plot_data2.sample(SAMPLE))\
            .mark_point(opacity=0.4) \
            .encode(x='x', y='y', color = alt.Color('label', scale= alt.Scale(domain=domain, range=range_)))\
            .interactive()

chart2 = alt.Chart(plot_data_drift.sample(SAMPLE)) \
            .mark_point(opacity=0.3, color = 'red') \
            .encode(x='x',y='y') \
            .interactive()


chart = chart1 + chart2
chart

# %%
plot_data_drift.sample(10)
# Out:
#        level_0  index         label  \
# 2345      2345   2345    legitimate
# 4784      4784   4784    legitimate
# 365        365    365    legitimate
# 626        626    626    legitimate
# 25547    25547   5547  drifted spam
# 22608    22608   2608  drifted spam
# 35487    35487  15487  drifted spam
# 6870      6870   6870    legitimate
# 7179      7179   7179    legitimate
# 31078    31078  11078  drifted spam
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              text  \
# 2345   I also like the way I like the regular Cappuccino and thought we would switch him to this a month ago and have never had proper smoked salmon or lox. I must put on a few months both he and his companion taken leave, than a glance from Jane invited her to come and buy wedding-clothes for herself and her children. So much the better. After the Chinese pet food scandal of 2007 that killed 1000's of our four legged friends...TELL AMAZON NOT TO SELL CHINESE CHICKEN JERKY. They were not off the Cobb, before the Harvilles met them. While settling this point, she was suddenly most impertinently interrupted in her employment by the entrance of Miss Crawford. Who is it? Yes; I remember, I asked you as soon as ever I open my mouth, shan't I? I have met with; and, between ourselves, the whole blame of it is to be hoped, more prosperous trial of the state: if duped, to be duped by a man of such amiable appearance as Wickham. John, the second, is named after his father.
# 4784                                                                                                                                                                                                                                                        The best part is...they aren't making her sick! I find that the tea is bold and robust without a bitter taste! What must be his principal, his only object of happiness. I enjoy flavored coffee and that it might belong only to the exceedingly great inconvenience of sending her carriage for the Miss Steeles, especially Lucy, they had never lived up to. It is caffeine free that's great for pregnant women and 80% of their unborn babies. Anne sometimes fancied she discerned him at a distance, but he never came. As to what restraint the apprehensions of disgrace in the corps might throw on a dishonourable elopement with her, I am not one of the window seats--but he reads all _them_ to himself. That reply will do for this.
# 365                                                                                                                                                                                                                                                                                                                                                                                                                                                                                She began to think he must have been in no hurry for the rest. Anne smiled more than once as he continued. After you put the 3 tablespoons in, there's an aftertaste, maybe from the dried leaves from my garden. A very short trial convinced her that every thing was soon in possession of a very wrong one. I cut open the pods and settled in Donwell. Whenever she is with us, Mrs. Cole does not know what to do with the Strafford family. Had it taken place only once a year, it would have been preferable to this.
# 626                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   To your Mother I related to them every other misfortune which had befallen me since we parted. I could get him to talk, he has plenty to say. Julia's elopement could affect her as it chose. However little known the feelings or the language of her own regard nor of its reasonableness. Had I known the product was excellent quality.
# 25547                                                                                                                                                                                                                                                                                                                                                                                                               Very good tasting, they also seem to be good, satisfying with 1 or more teaspoon of sugar. These are hard throughout without the chewy centers. These were easy to cook and it would win IMO. They have a waxy coating and some sort of feline version of steak and lobster. The original was a glowing review but apparently I'm not allowed to complete my purchase. I found that this tea is really pleasant and pairs perfectly with sweetener and half and like the coffee. My daughters friend is addicted to this treats zip bag, putting the treats in half, and she gobbles them up.
# 22608                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 I will definitly stock up next time I tried he knew I was going to switch our dog to a grain free diet to my pet because I love it because I don't have much more milk due to this product. He also cooks with it.The value for the money. Just look for a product that is intended for things that taste good, also don't buy this. Toss in a bullion cube into the boiling water before removal of the bag. We've only used it in cole slaw, hummus, havla, maccaroons & tabouli but I'm sure glad I did.
# 35487                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            This is one of the best noodles ever. This really is a very rare hot sauce, one of only two cat foods she likes. Easy and fast. They advertise 5-ways to eat it.
# 6870                                                                                                                                                                                                                                                                                                              I am just arrived. Mr. Crawford's business had been to Mrs. Goddard's that morning, and was in heaven! They sat without a fire; but that was all nothing. Imagine my surprise at finding myself thus seated amongst my old Acquaintance. I advise every body to begin dancing again. He concluded with representing to her the next day, took leave. It will save me a world of trouble and economy. I had no friend, no companion in my brother, and who perhaps after all, you know, the safer the child in the world. First consumed by the Greeks and Romans of long ago: simply cold-pressed in small batches, as some other chips from Amazon because they had high ratings. I think not.
# 7179                                                                                                                                                                                                                                                                                 To the girls, who could not reward him. Most bitterly did she cry. It is part of this speech, and saw his look, and felt what his sensations must be. The subject was pursued no farther, and the gentlemen parted the best of all is, that he is in their own estimation, and that of their immediate friends, the first private performers in England. These opinions had been hardly canvassed a year before another event arose of such importance in the family, as might fairly claim some place in his carriage. Catherine's blood ran cold with the horrid suggestions which naturally sprang from these words. The coffee itself didn't have a choice. CHAPTER XXXIV Edmund had great things to hear on his return.
# 31078                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     They taste better than home-made, with a hint of honey. I just received my caramels. It's pretty gross.
#
#               x         y
# 2345   0.590422 -0.044424
# 4784   0.553149 -0.005318
# 365    0.578106  0.027810
# 626    0.587026 -0.084848
# 25547       NaN       NaN
# 22608       NaN       NaN
# 35487       NaN       NaN
# 6870        NaN       NaN
# 7179        NaN       NaN
# 31078       NaN       NaN

# %%
STOP
import altair as alt
from altair.expr import datum
alt.renderers.enable('default')
SAMPLE = 2000

plot_data = pd.concat([df.reset_index(), pca_df], axis=1)
plot_data_drift = pd.concat([df.reset_index(), pca_df_drift], axis=1)

domain = ['legitimate', 'spam']
range_ = ['lightgray', 'blue']

chart1 = alt.Chart(plot_data.sample(SAMPLE)) \
            .mark_point(opacity=0.4) \
            .encode(x='x', y='y', \
                    color=alt.Color('label', scale = alt.Scale(domain=domain, range=range_)))\
            .interactive()

chart2 = alt.Chart(plot_data_drift.sample(SAMPLE)) \
            .mark_point(opacity=0.3, color = 'red') \
            .encode(x='x',y='y') \
            .interactive()


chart = chart1 + chart2
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8444ac890e8e> in <module>
# ----> 1 STOP
#       2 import altair as alt
#       3 from altair.expr import datum
#       4 alt.renderers.enable('default')
#       5 SAMPLE = 2000
#
# NameError: name 'STOP' is not defined

# %% [markdown]
# Seeing drifted spam emails in red and previous spam emails in blue, it looks like structure of spam has changed drastically. There's a good chance our model no longer performs as well as it used to. Utilizing pipelines, let's make predictions for the drifted spam data.

# %%
pipeline = Pipeline([
    ('features',feat_pipeline),
    ('model',model)
])

pipeline.fit(df_train["text"], df_train["label"])

# predict test instances
y_preds = pipeline.predict(df_test_spam["text"])
print(y_preds)

# %% [markdown]
# It looks as though the drifted data is mostly classified as legitimate (even though the entire test set was made of spam emails), but let's look at a confusion matrix to visualize the predictions.

# %%
from sklearn.metrics import confusion_matrix
from mlworkflows import plot

df, chart = plot.binary_confusion_matrix(df_test_spam["label"], y_preds)
df

# %% [markdown]
# Not surprisingly, the model is quite terrible at classifying drifted data, since these spam emails look very different than the spam emails we originally trained the model with.

# %% [markdown]
# From this exploration, we've been able to see that some change in the underlying data caused our model to be no longer useful. Because we simulated the drift, we know what is causing the problem, but this is usually not the case. Further exploration may be needed: is the drift gradual or abrupt? Was it a one time occurrence, or do you need to make seasonal adjustments to the model?
#
# We'll build a more formal test to check for drift using the [Alibi Detect](https://github.com/SeldonIO/alibi-detect) library.

# %%
import numpy as np

# change to numpy arrays in order to interact with KSDrift
array_test = np.asarray(df_test)
array_test_spam = np.asarray(df_test_spam)

# %% [markdown]
# While there are many methods of detection, we will display [Kolmogorov-Smirnov](https://en.wikipedia.org/wiki/Kolmogorov%E2%80%93Smirnov_test), or K-S, tests in this notebook to check for drift. These tests compare the probability distribution between original and (possibily) drifted data per feature. Looking at each feature's drift is helpful, but it is more important to prove the entire data set has changed in a statistically signficant way. Using a [Bonferroni](https://mathworld.wolfram.com/BonferroniCorrection.html) correction, the K-S test results are aggregated and tested as a whole.
#
# K-S tests are useful as they can detect imperceptible but statistically significant drift. However, this method only outputs whether or not drift has occurred and does not address questions on frequency or severity.

# %%
# KSDrift
import alibi_detect
from alibi_detect.cd import KSDrift
from sklearn import preprocessing

# initialize label encoder
label_encoder = preprocessing.LabelEncoder() 

p_val = 0.05
drift_detect = KSDrift(
    p_val = p_val, # p-value for KS test
    X_ref = array_test, # test against original test set
    preprocess_fn = pca, # other options: auto-encoder, softmax output
    preprocess_kwargs = {'model': label_encoder.fit(array_test[:,1]), 'batch_size':32},
    alternative = 'two-sided',  # other options: 'less', 'greater'
    correction = 'bonferroni' # other option: false discovery rate
)

# %% [markdown]
# We'll start with a sanity check and test the original data. Since we're feeding in the same data set twice, we should not get any drift.

# %%
preds_test = drift_detect.predict(array_test)
labels = ['No!', 'Yes!']
print('Has the data drifted? {}'.format(labels[preds_test['data']['is_drift']]))

# %% [markdown]
# This was the desired output! Let's try again, but with the drifted data.

# %%
preds_test = drift_detect.predict(array_test_spam)
print('Has the data drifted? {}'.format(labels[preds_test['data']['is_drift']]))

# %% [markdown]
# Great! Our drift detector can confirm that the data has drifted. Of course we already knew that there was drift since we created it ourselves, so doing K-S tests may have been overkill. However, this is a useful test when it isn't known if data has drifted or not.

# %% [markdown]
# Now we can both visualize and prove our data has drifted. This is important information, but what does this drift mean for our now-outdated model? *There is no one-size-fits-all answer to this question.* If your model is still performing well on the drifted data, you may choose to keep an eye on the performance metrics without taking any action. If your model suddenly cannot recognize a single spam email, it may be time to make changes to the model. Updates can look different; you may choose to:
#  - Retrain your model including the new data
#  - Test new parameters for a better fit
#  - Build a new model that suits the drifted data better
#
# or some combination of these techniques. We'll start with retraining the model while including the new pattern of spam data. This retraining could be done in a multitude of ways, but the simplest is to append the same Pride and Prejudice passage to a copy of the training spam data.

# %%
# append pride + prejudice to spam train 
pd.set_option('display.max_colwidth', None) 

# filter out spam training data
df_train_spam_drift = df_train[df_train.label == 'spam'].copy()

# add text to the start of the spam
df_train_spam_drift["text"] = df_train_spam_drift.text.apply(add_text, adds=pride_pred)
df_train_spam_drift

# %%
index = df_train.index
number_of_rows = len(index)
print(number_of_rows)

# %%
# append drifted spam data to df_train
df_train = df_train.append(df_train_spam_drift)

# %%
index = df_train.index
number_of_rows = len(index)
print(number_of_rows)

# %% [markdown]
# Great! We have a new dataset that should capture the same type of drift. Next, let's retrain the model and look at the results. While we wouldn't normally use accurary score (Can't remember why? Look at [this notebook.](./02-evaluating-models.ipynb)), because all of our test data is spam, there are no false positives or negatives.

# %%
# retrain model including drifted spam
pipeline.fit(df_train["text"], df_train["label"])

# predict test instances
y_preds = pipeline.predict(df_test_spam["text"])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(df_test_spam["label"], y_preds)

# %% [markdown]
# This new and improved model successfully identified all the drifted emails as spam! While most models won't be 100% accurate, the drift was significant and the training data reflected an identical drift. If the results were poor, our next step might have been to adjust the parameters set in previous notebooks or research a completely new model better suited for the new data set.

# %% [markdown]
# It's possible to put streamed data into piplines in order to automatically alert users when drift occurs and retrain the model. We look at integration services in [another notebook](07-services.ipynb) to better understand other capabilities.

# %% [markdown]
# ## Exercises
# The two models perform very similarly on the "drifted" data in this notebook. Consider alternative types of data drift and see how the models perform:
# 1. What happens when fewer words from Pride and Prejudice are appended to the spam?
# 2. How about using a completely different excerpt of Austen?
# 3. How do the models perform when generic text (neither Austen nor food reviews) is appended to the spam?
